# %% [markdown]
# # MNIST Images
# Ejemplo de TF usando MNIST, digitos escritos a mano

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
import tensorflow as tf
import numpy as np
from tensorflow import keras
# Out:
# 2024-12-26 08:41:10.820591: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-26 08:41:10.831251: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735198870.843355  101160 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735198870.846802  101160 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-26 08:41:10.858908: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Network and Training Parameters

# %%
# Network and Training Parameters
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES=10 # Number of Outputs/digits
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # How much Train is reserved for Validation

RESHAPED = 784

# %% [markdown]
# ## Loading MNIST DataSet

# %%
# Loading MNIST DataSet
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape(60000,RESHAPED)
X_test = X_test.reshape(10000,RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize
X_train /= 255.0
X_test /=255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(RESHAPED,),
                             name='dense_layer',
                             activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(RESHAPED,),
                             name='dense_layer_2',
                             activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
                             input_shape=(RESHAPED,),
                             name='dense_layer_3',
                             activation='softmax'))

model.summary()
# Out:
# /media/data/Proyectos/ia-gpu-m3/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1735198872.217169  101160 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1103 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_layer (Dense)             │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_layer_2 (Dense)           │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_layer_3 (Dense)           │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 118,282 (462.04 KB)
#  Trainable params: 118,282 (462.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Compiling the model

# %%
model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Trainning the model
# ## Trainning the model
# |PC|Time|
# |-|-|
# |Mac x86| - |
# |HP CPU| 1m28s|
# |HP GPU| 35s|

# %%
model.fit(X_train, Y_train,
          batch_size=BATCH_SIZE, epochs=EPOCHS,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1735198873.044614  101248 service.cc:148] XLA service 0x73f33c002570 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1735198873.044635  101248 service.cc:156]   StreamExecutor device (0): NVIDIA RTX A4000, Compute Capability 8.6
# 2024-12-26 08:41:13.057361: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1735198873.086698  101248 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2024-12-26 08:41:13.727953: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_47', 24 bytes spill stores, 24 bytes spill loads
#
# 2024-12-26 08:41:13.809243: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_179', 24 bytes spill stores, 24 bytes spill loads
#
# 2024-12-26 08:41:14.512822: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_177', 124 bytes spill stores, 124 bytes spill loads
#
# 2024-12-26 08:41:14.584358: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_177', 60 bytes spill stores, 60 bytes spill loads
#  84/375 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1788 - loss: 2.2733
# I0000 00:00:1735198875.324505  101248 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 370/375 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4195 - loss: 1.9375
# 2024-12-26 08:41:17.149833: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_47', 12 bytes spill stores, 12 bytes spill loads
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.4226 - loss: 1.9307 - val_accuracy: 0.8352 - val_loss: 0.7770
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8390 - loss: 0.6896 - val_accuracy: 0.8825 - val_loss: 0.4673
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8752 - loss: 0.4684 - val_accuracy: 0.8994 - val_loss: 0.3816
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8915 - loss: 0.3917 - val_accuracy: 0.9071 - val_loss: 0.3411
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8994 - loss: 0.3571 - val_accuracy: 0.9126 - val_loss: 0.3152
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9072 - loss: 0.3274 - val_accuracy: 0.9149 - val_loss: 0.2973
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9125 - loss: 0.3105 - val_accuracy: 0.9187 - val_loss: 0.2846
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9171 - loss: 0.2882 - val_accuracy: 0.9220 - val_loss: 0.2707
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9226 - loss: 0.2738 - val_accuracy: 0.9256 - val_loss: 0.2610
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9231 - loss: 0.2718 - val_accuracy: 0.9286 - val_loss: 0.2507
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9268 - loss: 0.2546 - val_accuracy: 0.9299 - val_loss: 0.2434
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9284 - loss: 0.2468 - val_accuracy: 0.9313 - val_loss: 0.2351
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9302 - loss: 0.2413 - val_accuracy: 0.9340 - val_loss: 0.2289
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9320 - loss: 0.2384 - val_accuracy: 0.9357 - val_loss: 0.2243
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9368 - loss: 0.2186 - val_accuracy: 0.9368 - val_loss: 0.2162
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9368 - loss: 0.2193 - val_accuracy: 0.9390 - val_loss: 0.2120
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9384 - loss: 0.2158 - val_accuracy: 0.9404 - val_loss: 0.2077
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9387 - loss: 0.2093 - val_accuracy: 0.9426 - val_loss: 0.2024
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9407 - loss: 0.2036 - val_accuracy: 0.9438 - val_loss: 0.1987
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9408 - loss: 0.2027 - val_accuracy: 0.9445 - val_loss: 0.1936
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9459 - loss: 0.1898 - val_accuracy: 0.9457 - val_loss: 0.1895
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9469 - loss: 0.1855 - val_accuracy: 0.9474 - val_loss: 0.1859
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9492 - loss: 0.1828 - val_accuracy: 0.9482 - val_loss: 0.1815
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9474 - loss: 0.1828 - val_accuracy: 0.9492 - val_loss: 0.1781
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9491 - loss: 0.1762 - val_accuracy: 0.9498 - val_loss: 0.1757
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9505 - loss: 0.1729 - val_accuracy: 0.9503 - val_loss: 0.1733
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9520 - loss: 0.1659 - val_accuracy: 0.9517 - val_loss: 0.1702
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9529 - loss: 0.1617 - val_accuracy: 0.9529 - val_loss: 0.1676
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9525 - loss: 0.1608 - val_accuracy: 0.9531 - val_loss: 0.1656
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9565 - loss: 0.1527 - val_accuracy: 0.9542 - val_loss: 0.1629
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9568 - loss: 0.1481 - val_accuracy: 0.9550 - val_loss: 0.1597
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9556 - loss: 0.1525 - val_accuracy: 0.9556 - val_loss: 0.1575
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9566 - loss: 0.1500 - val_accuracy: 0.9561 - val_loss: 0.1553
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9591 - loss: 0.1421 - val_accuracy: 0.9570 - val_loss: 0.1531
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9592 - loss: 0.1439 - val_accuracy: 0.9572 - val_loss: 0.1521
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9591 - loss: 0.1395 - val_accuracy: 0.9576 - val_loss: 0.1492
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9617 - loss: 0.1342 - val_accuracy: 0.9591 - val_loss: 0.1467
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9628 - loss: 0.1310 - val_accuracy: 0.9584 - val_loss: 0.1453
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9630 - loss: 0.1313 - val_accuracy: 0.9583 - val_loss: 0.1441
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9632 - loss: 0.1280 - val_accuracy: 0.9602 - val_loss: 0.1416
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9635 - loss: 0.1280 - val_accuracy: 0.9607 - val_loss: 0.1405
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9637 - loss: 0.1297 - val_accuracy: 0.9607 - val_loss: 0.1385
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9653 - loss: 0.1216 - val_accuracy: 0.9613 - val_loss: 0.1369
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9666 - loss: 0.1158 - val_accuracy: 0.9615 - val_loss: 0.1359
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9688 - loss: 0.1116 - val_accuracy: 0.9611 - val_loss: 0.1349
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9680 - loss: 0.1133 - val_accuracy: 0.9612 - val_loss: 0.1341
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9665 - loss: 0.1183 - val_accuracy: 0.9617 - val_loss: 0.1331
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9695 - loss: 0.1072 - val_accuracy: 0.9634 - val_loss: 0.1304
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9700 - loss: 0.1086 - val_accuracy: 0.9634 - val_loss: 0.1289
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9701 - loss: 0.1057 - val_accuracy: 0.9638 - val_loss: 0.1287

# %% [markdown]
# ## Evaluate the model

# %%
test_loss, test_acc = model.evaluate(X_test,Y_test)
print('Test Accuracy', test_acc)
# Out:
# 2024-12-26 08:41:48.751927: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_54', 4 bytes spill stores, 4 bytes spill loads
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9565 - loss: 0.1442
# Test Accuracy 0.9632999897003174
