# %% [markdown]
# # MNIST Images
# Ejemplo de TF usando MNIST, digitos escritos a mano

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
# Out:
# 2024-12-24 14:10:15.979202: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Network and Training Parameters

# %%
# Network and Training Parameters
EPOCHS = 50
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES=10 # Number of Outputs/digits
N_HIDDEN = 128
VALIDATION_SPLIT = 0.2 # How much Train is reserved for Validation

RESHAPED = 784

# %% [markdown]
# ## Loading MNIST DataSet

# %%
# Loading MNIST DataSet
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = X_train.reshape(60000,RESHAPED)
X_test = X_test.reshape(10000,RESHAPED)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalize
X_train /= 255.0
X_test /=255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## Build the model

# %%
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(RESHAPED,),
                             name='dense_layer',
                             activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,
                             input_shape=(RESHAPED,),
                             name='dense_layer_2',
                             activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
                             input_shape=(RESHAPED,),
                             name='dense_layer_3',
                             activation='softmax'))

model.summary()
# Out:
# /Users/daniel/Proyectos/ia-gpu-m3/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       1 model = tf.keras.models.Sequential()
#       2 model.add(keras.layers.Dense(N_HIDDEN,
#       3                              input_shape=(RESHAPED,),
#       4                              name='dense_layer',
#       5                              activation='relu'))
# ----> 6 model.add(keras.layers.Dense(N_HIDDEN,
#       7                              input_shape=(RESHAPED,),
#       8                              name='dense_layer',
#       9                              activation='relu'))
#      10 model.add(keras.layers.Dense(NB_CLASSES,
#      11                              input_shape=(RESHAPED,),
#      12                              name='dense_layer',
#      13                              activation='softmax'))
#      15 model.summary()
#
# File ~/Proyectos/ia-gpu-m3/.venv/lib/python3.11/site-packages/keras/src/models/sequential.py:103, in Sequential.add(self, layer, rebuild)
#      97     raise ValueError(
#      98         "Only instances of `keras.Layer` can be "
#      99         f"added to a Sequential model. Received: {layer} "
#     100         f"(of type {type(layer)})"
#     101     )
#     102 if not self._is_layer_name_unique(layer):
# --> 103     raise ValueError(
#     104         "All layers added to a Sequential model "
#     105         f"should have unique names. Name '{layer.name}' is already "
#     106         "the name of a layer in this model. Update the `name` argument "
#     107         "to pass a unique name."
#     108     )
#     109 if (
#     110     isinstance(layer, InputLayer)
#     111     and self._layers
#     112     and isinstance(self._layers[0], InputLayer)
#     113 ):
#     114     raise ValueError(
#     115         f"Sequential model '{self.name}' has already been configured "
#     116         f"to use input shape {self._layers[0].batch_shape}. You cannot "
#     117         f"add a different Input layer to it."
#     118     )
#
# ValueError: All layers added to a Sequential model should have unique names. Name 'dense_layer' is already the name of a layer in this model. Update the `name` argument to pass a unique name.

# %% [markdown]
# ## Compiling the model

# %%
model.compile(optimizer='SGD',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Trainning the model

# %%
model.fit(X_train, Y_train,
          batch_size=BATCH_SIZE, epochs=EPOCHS,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4885 - loss: 1.7532 - val_accuracy: 0.8313 - val_loss: 0.8919
# Epoch 2/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8206 - loss: 0.8530 - val_accuracy: 0.8584 - val_loss: 0.6553
# Epoch 3/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8471 - loss: 0.6687 - val_accuracy: 0.8702 - val_loss: 0.5603
# Epoch 4/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8616 - loss: 0.5794 - val_accuracy: 0.8789 - val_loss: 0.5077
# Epoch 5/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8675 - loss: 0.5341 - val_accuracy: 0.8848 - val_loss: 0.4735
# Epoch 6/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8767 - loss: 0.4972 - val_accuracy: 0.8883 - val_loss: 0.4494
# Epoch 7/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8781 - loss: 0.4792 - val_accuracy: 0.8900 - val_loss: 0.4316
# Epoch 8/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8818 - loss: 0.4585 - val_accuracy: 0.8923 - val_loss: 0.4173
# Epoch 9/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8818 - loss: 0.4507 - val_accuracy: 0.8945 - val_loss: 0.4058
# Epoch 10/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8843 - loss: 0.4337 - val_accuracy: 0.8951 - val_loss: 0.3965
# Epoch 11/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8858 - loss: 0.4289 - val_accuracy: 0.8982 - val_loss: 0.3882
# Epoch 12/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8912 - loss: 0.4097 - val_accuracy: 0.8982 - val_loss: 0.3812
# Epoch 13/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8897 - loss: 0.4081 - val_accuracy: 0.8999 - val_loss: 0.3751
# Epoch 14/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8884 - loss: 0.4062 - val_accuracy: 0.9014 - val_loss: 0.3699
# Epoch 15/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8933 - loss: 0.3924 - val_accuracy: 0.9028 - val_loss: 0.3650
# Epoch 16/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8941 - loss: 0.3855 - val_accuracy: 0.9035 - val_loss: 0.3608
# Epoch 17/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8950 - loss: 0.3854 - val_accuracy: 0.9037 - val_loss: 0.3570
# Epoch 18/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8969 - loss: 0.3762 - val_accuracy: 0.9044 - val_loss: 0.3535
# Epoch 19/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8938 - loss: 0.3828 - val_accuracy: 0.9050 - val_loss: 0.3504
# Epoch 20/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8992 - loss: 0.3713 - val_accuracy: 0.9056 - val_loss: 0.3473
# Epoch 21/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8979 - loss: 0.3696 - val_accuracy: 0.9062 - val_loss: 0.3447
# Epoch 22/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8972 - loss: 0.3670 - val_accuracy: 0.9077 - val_loss: 0.3420
# Epoch 23/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9002 - loss: 0.3611 - val_accuracy: 0.9073 - val_loss: 0.3396
# Epoch 24/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9033 - loss: 0.3561 - val_accuracy: 0.9084 - val_loss: 0.3374
# Epoch 25/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9015 - loss: 0.3545 - val_accuracy: 0.9086 - val_loss: 0.3355
# Epoch 26/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9028 - loss: 0.3563 - val_accuracy: 0.9092 - val_loss: 0.3335
# Epoch 27/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8999 - loss: 0.3566 - val_accuracy: 0.9094 - val_loss: 0.3318
# Epoch 28/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9033 - loss: 0.3510 - val_accuracy: 0.9107 - val_loss: 0.3299
# Epoch 29/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9040 - loss: 0.3448 - val_accuracy: 0.9103 - val_loss: 0.3283
# Epoch 30/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9051 - loss: 0.3442 - val_accuracy: 0.9109 - val_loss: 0.3267
# Epoch 31/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9063 - loss: 0.3415 - val_accuracy: 0.9118 - val_loss: 0.3254
# Epoch 32/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9060 - loss: 0.3398 - val_accuracy: 0.9121 - val_loss: 0.3240
# Epoch 33/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9049 - loss: 0.3456 - val_accuracy: 0.9118 - val_loss: 0.3225
# Epoch 34/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9057 - loss: 0.3428 - val_accuracy: 0.9121 - val_loss: 0.3213
# Epoch 35/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9054 - loss: 0.3386 - val_accuracy: 0.9122 - val_loss: 0.3200
# Epoch 36/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9072 - loss: 0.3336 - val_accuracy: 0.9128 - val_loss: 0.3189
# Epoch 37/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9056 - loss: 0.3379 - val_accuracy: 0.9128 - val_loss: 0.3179
# Epoch 38/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9071 - loss: 0.3343 - val_accuracy: 0.9132 - val_loss: 0.3168
# Epoch 39/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9049 - loss: 0.3382 - val_accuracy: 0.9134 - val_loss: 0.3157
# Epoch 40/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9078 - loss: 0.3320 - val_accuracy: 0.9135 - val_loss: 0.3148
# Epoch 41/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9088 - loss: 0.3290 - val_accuracy: 0.9137 - val_loss: 0.3138
# Epoch 42/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9106 - loss: 0.3201 - val_accuracy: 0.9138 - val_loss: 0.3130
# Epoch 43/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9049 - loss: 0.3332 - val_accuracy: 0.9136 - val_loss: 0.3120
# Epoch 44/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9095 - loss: 0.3201 - val_accuracy: 0.9136 - val_loss: 0.3113
# Epoch 45/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9074 - loss: 0.3273 - val_accuracy: 0.9146 - val_loss: 0.3104
# Epoch 46/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9110 - loss: 0.3234 - val_accuracy: 0.9147 - val_loss: 0.3096
# Epoch 47/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9061 - loss: 0.3286 - val_accuracy: 0.9147 - val_loss: 0.3089
# Epoch 48/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9120 - loss: 0.3215 - val_accuracy: 0.9149 - val_loss: 0.3082
# Epoch 49/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9108 - loss: 0.3178 - val_accuracy: 0.9150 - val_loss: 0.3075
# Epoch 50/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9104 - loss: 0.3246 - val_accuracy: 0.9154 - val_loss: 0.3068
# Epoch 51/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9129 - loss: 0.3142 - val_accuracy: 0.9153 - val_loss: 0.3060
# Epoch 52/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9095 - loss: 0.3208 - val_accuracy: 0.9152 - val_loss: 0.3056
# Epoch 53/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9131 - loss: 0.3129 - val_accuracy: 0.9153 - val_loss: 0.3048
# Epoch 54/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9109 - loss: 0.3169 - val_accuracy: 0.9157 - val_loss: 0.3041
# Epoch 55/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9119 - loss: 0.3133 - val_accuracy: 0.9158 - val_loss: 0.3036
# Epoch 56/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9132 - loss: 0.3128 - val_accuracy: 0.9158 - val_loss: 0.3030
# Epoch 57/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9127 - loss: 0.3162 - val_accuracy: 0.9166 - val_loss: 0.3024
# Epoch 58/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9124 - loss: 0.3195 - val_accuracy: 0.9161 - val_loss: 0.3019
# Epoch 59/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9123 - loss: 0.3133 - val_accuracy: 0.9166 - val_loss: 0.3014
# Epoch 60/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9113 - loss: 0.3151 - val_accuracy: 0.9165 - val_loss: 0.3008
# Epoch 61/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9139 - loss: 0.3132 - val_accuracy: 0.9163 - val_loss: 0.3003
# Epoch 62/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9148 - loss: 0.3055 - val_accuracy: 0.9165 - val_loss: 0.2999
# Epoch 63/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9117 - loss: 0.3130 - val_accuracy: 0.9168 - val_loss: 0.2995
# Epoch 64/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9133 - loss: 0.3098 - val_accuracy: 0.9170 - val_loss: 0.2990
# Epoch 65/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9121 - loss: 0.3136 - val_accuracy: 0.9168 - val_loss: 0.2985
# Epoch 66/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9149 - loss: 0.3055 - val_accuracy: 0.9166 - val_loss: 0.2981
# Epoch 67/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9131 - loss: 0.3119 - val_accuracy: 0.9168 - val_loss: 0.2977
# Epoch 68/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9132 - loss: 0.3102 - val_accuracy: 0.9165 - val_loss: 0.2973
# Epoch 69/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9140 - loss: 0.3058 - val_accuracy: 0.9175 - val_loss: 0.2969
# Epoch 70/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9153 - loss: 0.3046 - val_accuracy: 0.9175 - val_loss: 0.2964
# Epoch 71/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9144 - loss: 0.3025 - val_accuracy: 0.9175 - val_loss: 0.2960
# Epoch 72/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9136 - loss: 0.3106 - val_accuracy: 0.9178 - val_loss: 0.2957
# Epoch 73/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9138 - loss: 0.3133 - val_accuracy: 0.9178 - val_loss: 0.2953
# Epoch 74/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9166 - loss: 0.3034 - val_accuracy: 0.9179 - val_loss: 0.2949
# Epoch 75/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9150 - loss: 0.3027 - val_accuracy: 0.9174 - val_loss: 0.2946
# Epoch 76/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9149 - loss: 0.3072 - val_accuracy: 0.9178 - val_loss: 0.2942
# Epoch 77/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9168 - loss: 0.2978 - val_accuracy: 0.9181 - val_loss: 0.2939
# Epoch 78/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9145 - loss: 0.3065 - val_accuracy: 0.9181 - val_loss: 0.2935
# Epoch 79/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9153 - loss: 0.3048 - val_accuracy: 0.9181 - val_loss: 0.2932
# Epoch 80/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9147 - loss: 0.3065 - val_accuracy: 0.9185 - val_loss: 0.2929
# Epoch 81/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9160 - loss: 0.3039 - val_accuracy: 0.9186 - val_loss: 0.2926
# Epoch 82/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9153 - loss: 0.3026 - val_accuracy: 0.9187 - val_loss: 0.2922
# Epoch 83/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9168 - loss: 0.2951 - val_accuracy: 0.9189 - val_loss: 0.2920
# Epoch 84/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9157 - loss: 0.3009 - val_accuracy: 0.9184 - val_loss: 0.2917
# Epoch 85/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9149 - loss: 0.2990 - val_accuracy: 0.9187 - val_loss: 0.2914
# Epoch 86/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9155 - loss: 0.3041 - val_accuracy: 0.9189 - val_loss: 0.2910
# Epoch 87/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9161 - loss: 0.3038 - val_accuracy: 0.9191 - val_loss: 0.2908
# Epoch 88/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9144 - loss: 0.3061 - val_accuracy: 0.9192 - val_loss: 0.2906
# Epoch 89/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9177 - loss: 0.2949 - val_accuracy: 0.9191 - val_loss: 0.2902
# Epoch 90/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9166 - loss: 0.2990 - val_accuracy: 0.9194 - val_loss: 0.2900
# Epoch 91/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9167 - loss: 0.2971 - val_accuracy: 0.9195 - val_loss: 0.2896
# Epoch 92/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9144 - loss: 0.3074 - val_accuracy: 0.9197 - val_loss: 0.2896
# Epoch 93/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9165 - loss: 0.3021 - val_accuracy: 0.9193 - val_loss: 0.2892
# Epoch 94/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9169 - loss: 0.2990 - val_accuracy: 0.9197 - val_loss: 0.2890
# Epoch 95/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9156 - loss: 0.3005 - val_accuracy: 0.9196 - val_loss: 0.2887
# Epoch 96/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9151 - loss: 0.3022 - val_accuracy: 0.9193 - val_loss: 0.2885
# Epoch 97/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2939 - val_accuracy: 0.9196 - val_loss: 0.2882
# Epoch 98/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9174 - loss: 0.2978 - val_accuracy: 0.9195 - val_loss: 0.2881
# Epoch 99/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9183 - loss: 0.2904 - val_accuracy: 0.9197 - val_loss: 0.2878
# Epoch 100/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9197 - loss: 0.2899 - val_accuracy: 0.9196 - val_loss: 0.2875
# Epoch 101/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9174 - loss: 0.2966 - val_accuracy: 0.9198 - val_loss: 0.2873
# Epoch 102/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2930 - val_accuracy: 0.9198 - val_loss: 0.2871
# Epoch 103/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9193 - loss: 0.2882 - val_accuracy: 0.9200 - val_loss: 0.2869
# Epoch 104/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9193 - loss: 0.2875 - val_accuracy: 0.9197 - val_loss: 0.2867
# Epoch 105/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9175 - loss: 0.2950 - val_accuracy: 0.9198 - val_loss: 0.2865
# Epoch 106/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9194 - loss: 0.2910 - val_accuracy: 0.9201 - val_loss: 0.2864
# Epoch 107/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9185 - loss: 0.2868 - val_accuracy: 0.9199 - val_loss: 0.2861
# Epoch 108/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9188 - loss: 0.2919 - val_accuracy: 0.9202 - val_loss: 0.2859
# Epoch 109/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9198 - loss: 0.2884 - val_accuracy: 0.9202 - val_loss: 0.2857
# Epoch 110/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9172 - loss: 0.2949 - val_accuracy: 0.9202 - val_loss: 0.2856
# Epoch 111/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9177 - loss: 0.2961 - val_accuracy: 0.9204 - val_loss: 0.2853
# Epoch 112/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9162 - loss: 0.2959 - val_accuracy: 0.9206 - val_loss: 0.2852
# Epoch 113/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2908 - val_accuracy: 0.9208 - val_loss: 0.2850
# Epoch 114/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9179 - loss: 0.2935 - val_accuracy: 0.9205 - val_loss: 0.2849
# Epoch 115/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9204 - loss: 0.2851 - val_accuracy: 0.9208 - val_loss: 0.2846
# Epoch 116/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9187 - loss: 0.2854 - val_accuracy: 0.9208 - val_loss: 0.2844
# Epoch 117/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9179 - loss: 0.2874 - val_accuracy: 0.9207 - val_loss: 0.2843
# Epoch 118/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9220 - loss: 0.2819 - val_accuracy: 0.9210 - val_loss: 0.2840
# Epoch 119/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9171 - loss: 0.2944 - val_accuracy: 0.9207 - val_loss: 0.2840
# Epoch 120/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9188 - loss: 0.2860 - val_accuracy: 0.9210 - val_loss: 0.2838
# Epoch 121/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9190 - loss: 0.2899 - val_accuracy: 0.9212 - val_loss: 0.2836
# Epoch 122/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9190 - loss: 0.2872 - val_accuracy: 0.9213 - val_loss: 0.2834
# Epoch 123/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9191 - loss: 0.2881 - val_accuracy: 0.9215 - val_loss: 0.2832
# Epoch 124/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9209 - loss: 0.2855 - val_accuracy: 0.9214 - val_loss: 0.2831
# Epoch 125/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2855 - val_accuracy: 0.9217 - val_loss: 0.2829
# Epoch 126/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9176 - loss: 0.2883 - val_accuracy: 0.9217 - val_loss: 0.2828
# Epoch 127/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9184 - loss: 0.2890 - val_accuracy: 0.9218 - val_loss: 0.2827
# Epoch 128/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9180 - loss: 0.2932 - val_accuracy: 0.9214 - val_loss: 0.2826
# Epoch 129/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9223 - loss: 0.2801 - val_accuracy: 0.9215 - val_loss: 0.2824
# Epoch 130/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9191 - loss: 0.2898 - val_accuracy: 0.9217 - val_loss: 0.2822
# Epoch 131/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9186 - loss: 0.2904 - val_accuracy: 0.9218 - val_loss: 0.2820
# Epoch 132/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2826 - val_accuracy: 0.9224 - val_loss: 0.2819
# Epoch 133/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9203 - loss: 0.2875 - val_accuracy: 0.9220 - val_loss: 0.2819
# Epoch 134/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9181 - loss: 0.2881 - val_accuracy: 0.9218 - val_loss: 0.2816
# Epoch 135/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9184 - loss: 0.2933 - val_accuracy: 0.9221 - val_loss: 0.2816
# Epoch 136/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9180 - loss: 0.2840 - val_accuracy: 0.9218 - val_loss: 0.2814
# Epoch 137/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9204 - loss: 0.2862 - val_accuracy: 0.9219 - val_loss: 0.2813
# Epoch 138/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9203 - loss: 0.2827 - val_accuracy: 0.9220 - val_loss: 0.2811
# Epoch 139/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.2855 - val_accuracy: 0.9223 - val_loss: 0.2810
# Epoch 140/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9224 - loss: 0.2821 - val_accuracy: 0.9221 - val_loss: 0.2809
# Epoch 141/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9197 - loss: 0.2875 - val_accuracy: 0.9222 - val_loss: 0.2808
# Epoch 142/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9206 - loss: 0.2849 - val_accuracy: 0.9225 - val_loss: 0.2807
# Epoch 143/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9209 - loss: 0.2832 - val_accuracy: 0.9227 - val_loss: 0.2806
# Epoch 144/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9218 - loss: 0.2774 - val_accuracy: 0.9225 - val_loss: 0.2804
# Epoch 145/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9195 - loss: 0.2808 - val_accuracy: 0.9226 - val_loss: 0.2803
# Epoch 146/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9201 - loss: 0.2848 - val_accuracy: 0.9225 - val_loss: 0.2801
# Epoch 147/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9194 - loss: 0.2895 - val_accuracy: 0.9226 - val_loss: 0.2800
# Epoch 148/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9201 - loss: 0.2850 - val_accuracy: 0.9223 - val_loss: 0.2799
# Epoch 149/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9221 - loss: 0.2819 - val_accuracy: 0.9228 - val_loss: 0.2798
# Epoch 150/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9181 - loss: 0.2938 - val_accuracy: 0.9231 - val_loss: 0.2797
# Epoch 151/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9213 - loss: 0.2824 - val_accuracy: 0.9225 - val_loss: 0.2796
# Epoch 152/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9214 - loss: 0.2797 - val_accuracy: 0.9224 - val_loss: 0.2794
# Epoch 153/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9232 - loss: 0.2748 - val_accuracy: 0.9227 - val_loss: 0.2793
# Epoch 154/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9205 - loss: 0.2860 - val_accuracy: 0.9232 - val_loss: 0.2792
# Epoch 155/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9225 - loss: 0.2790 - val_accuracy: 0.9227 - val_loss: 0.2792
# Epoch 156/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9193 - loss: 0.2860 - val_accuracy: 0.9228 - val_loss: 0.2790
# Epoch 157/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9184 - loss: 0.2867 - val_accuracy: 0.9227 - val_loss: 0.2789
# Epoch 158/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9222 - loss: 0.2787 - val_accuracy: 0.9233 - val_loss: 0.2788
# Epoch 159/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9218 - loss: 0.2815 - val_accuracy: 0.9230 - val_loss: 0.2787
# Epoch 160/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.2801 - val_accuracy: 0.9233 - val_loss: 0.2787
# Epoch 161/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9190 - loss: 0.2851 - val_accuracy: 0.9232 - val_loss: 0.2785
# Epoch 162/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9216 - loss: 0.2784 - val_accuracy: 0.9227 - val_loss: 0.2784
# Epoch 163/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9224 - loss: 0.2810 - val_accuracy: 0.9231 - val_loss: 0.2783
# Epoch 164/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9209 - loss: 0.2833 - val_accuracy: 0.9232 - val_loss: 0.2782
# Epoch 165/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9226 - loss: 0.2783 - val_accuracy: 0.9231 - val_loss: 0.2781
# Epoch 166/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9216 - loss: 0.2836 - val_accuracy: 0.9229 - val_loss: 0.2781
# Epoch 167/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9214 - loss: 0.2810 - val_accuracy: 0.9232 - val_loss: 0.2780
# Epoch 168/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9208 - loss: 0.2839 - val_accuracy: 0.9233 - val_loss: 0.2780
# Epoch 169/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9231 - loss: 0.2771 - val_accuracy: 0.9230 - val_loss: 0.2778
# Epoch 170/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9212 - loss: 0.2825 - val_accuracy: 0.9232 - val_loss: 0.2777
# Epoch 171/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9231 - loss: 0.2770 - val_accuracy: 0.9233 - val_loss: 0.2776
# Epoch 172/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9214 - loss: 0.2811 - val_accuracy: 0.9232 - val_loss: 0.2775
# Epoch 173/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9217 - loss: 0.2786 - val_accuracy: 0.9232 - val_loss: 0.2774
# Epoch 174/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9236 - loss: 0.2734 - val_accuracy: 0.9232 - val_loss: 0.2773
# Epoch 175/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9239 - loss: 0.2759 - val_accuracy: 0.9227 - val_loss: 0.2773
# Epoch 176/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9234 - loss: 0.2740 - val_accuracy: 0.9233 - val_loss: 0.2772
# Epoch 177/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9200 - loss: 0.2841 - val_accuracy: 0.9229 - val_loss: 0.2771
# Epoch 178/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9227 - loss: 0.2709 - val_accuracy: 0.9233 - val_loss: 0.2769
# Epoch 179/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9212 - loss: 0.2808 - val_accuracy: 0.9234 - val_loss: 0.2768
# Epoch 180/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9230 - loss: 0.2800 - val_accuracy: 0.9234 - val_loss: 0.2768
# Epoch 181/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9232 - loss: 0.2769 - val_accuracy: 0.9230 - val_loss: 0.2768
# Epoch 182/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9215 - loss: 0.2786 - val_accuracy: 0.9235 - val_loss: 0.2767
# Epoch 183/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9205 - loss: 0.2862 - val_accuracy: 0.9235 - val_loss: 0.2765
# Epoch 184/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9234 - loss: 0.2722 - val_accuracy: 0.9233 - val_loss: 0.2766
# Epoch 185/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9227 - loss: 0.2742 - val_accuracy: 0.9234 - val_loss: 0.2764
# Epoch 186/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9226 - loss: 0.2719 - val_accuracy: 0.9234 - val_loss: 0.2763
# Epoch 187/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9231 - loss: 0.2715 - val_accuracy: 0.9238 - val_loss: 0.2763
# Epoch 188/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9249 - loss: 0.2723 - val_accuracy: 0.9235 - val_loss: 0.2762
# Epoch 189/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9218 - loss: 0.2760 - val_accuracy: 0.9233 - val_loss: 0.2761
# Epoch 190/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9238 - loss: 0.2783 - val_accuracy: 0.9233 - val_loss: 0.2760
# Epoch 191/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9216 - loss: 0.2846 - val_accuracy: 0.9234 - val_loss: 0.2760
# Epoch 192/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9232 - loss: 0.2756 - val_accuracy: 0.9238 - val_loss: 0.2759
# Epoch 193/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9229 - loss: 0.2750 - val_accuracy: 0.9233 - val_loss: 0.2759
# Epoch 194/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9231 - loss: 0.2742 - val_accuracy: 0.9234 - val_loss: 0.2757
# Epoch 195/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9227 - loss: 0.2757 - val_accuracy: 0.9234 - val_loss: 0.2756
# Epoch 196/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9246 - loss: 0.2708 - val_accuracy: 0.9236 - val_loss: 0.2756
# Epoch 197/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9229 - loss: 0.2755 - val_accuracy: 0.9237 - val_loss: 0.2755
# Epoch 198/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9236 - loss: 0.2731 - val_accuracy: 0.9237 - val_loss: 0.2754
# Epoch 199/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9246 - loss: 0.2722 - val_accuracy: 0.9234 - val_loss: 0.2754
# Epoch 200/200
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9237 - loss: 0.2780 - val_accuracy: 0.9235 - val_loss: 0.2753

# %% [markdown]
# ## Evaluate the model

# %%
test_loss, test_acc = model.evaluate(X_test,Y_test)
print('Test Accuracy', test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9104 - loss: 0.3160
# Test Accuracy 0.9223999977111816
